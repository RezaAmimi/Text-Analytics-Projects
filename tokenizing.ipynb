# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/mine/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
class NBClassifier:


    def calc_statistics(self, features, target):
        '''
        calculate mean, variance for each column and convert to numpy array
        ''' 
        self.mean = features.groupby(target).apply(np.mean).to_numpy()
        self.var = features.groupby(target).apply(np.var).to_numpy()

        return self.mean, self.var

    def gaussian_density(self, class_idx, x):     
        '''
        calculate probability from gaussian density function (normally distributed)
        '''
        mean = self.mean[class_idx]
        var = self.var[class_idx]
        numerator = np.exp((-1/2)*((x-mean)**2) / (2 * var))
        denominator = np.sqrt(2 * np.pi * var)
        prob = numerator / denominator
        return prob

    # prior probabilities
    def calc_prior(self, features, target):
        self.prior = (features.groupby(target).apply(lambda x: len(x))/self.rows).to_numpy()
        return self.prior

    # posterior probabilities
    def calc_posterior(self, x):
        posteriors = []
        for i in range(self.count):
            prior = np.log(self.prior[i]) 
            conditional = np.sum(np.log(self.gaussian_density(i, x)))
            posterior = prior + conditional
            posteriors.append(posterior)
        return self.classes[np.argmax(posteriors)]

    def fit(self, features, target):
        # define class variables 
        self.classes = np.unique(target)
        self.count = len(self.classes)
        self.feature_nums = features.shape[1]
        self.rows = features.shape[0]

        # calculate statistics    
        self.calc_statistics(features, target)
        self.calc_prior(features, target)

    def predict(self, features):
        preds = [self.calc_posterior(f) for f in features.to_numpy()]
        return preds

# %%
iris = datasets.load_iris()
features_train = pd.DataFrame(iris.data[1:100,:])
features_test = pd.DataFrame(iris.data[100:,:])
target_train = pd.Series(iris.target[1:100])
target_test = pd.Series(iris.target[100:])

# %%
a = NBClassifier()
a.fit(features_train, target_train)
a.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c7767d99e266> in <module>
#       1 a = NBClassifier()
#       2 a.fit(features_train, target_train)
# ----> 3 a.predict()
#
# TypeError: predict() missing 1 required positional argument: 'features'

# %%
# Using readlines()
file1 = open('train.data', 'r')
Lines = file1.readlines()
 
count = 0
# Strips the newline character 
Moein = stopwords.words('english')
for i in range(len(Moein)):
    Moein[i] = Moein[i].lower()
    
Moein2 = [',','.','`',"'",'--']

for line in Lines:
    A = line.split("|")
    word, non = A[0].split(".")
    sense = A[1]
    context = A[2]
    context = context.split("%%")
    word_in_context = context[1]
    feature_left = context[0].split(" ")
    feature_right = context[2].split(" ")
    feature = []
    count1 = 1
    count2 = 0
    while (1):
        if count1 < len(feature_left):
            if ((len(feature_left[-count1]) > 1) and (feature_left[-count1].lower() not in Moein) and (set(list(feature_left[-count1])) - set(Moein2)) == set(list(feature_left[-count1]))):
                feature.append(feature_left[-count1])
                count1 = count1 + 1
            else:
                count1 = count1 + 1
        if len(feature) == 6:
            break
        if count2 < len(feature_right):
            if ((len(feature_right[count2]) > 1) and (feature_right[count2].lower() not in Moein) and (set(list(feature_right[count2])) - set(Moein2)) == set(list(feature_right[count2]))):
                feature.append(feature_right[count2])
                count2 = count2 + 1
            else:
                count2 = count2 + 1
        if len(feature) == 6:
            break
    print("word: ", word)
    print("non: ", non)
    print("sense: ", sense)
    print("features: ", feature)
    print(count1, count2)
    print("--------------------------------")
# Out:
# word:  affect
# non:  v
# sense:   1
# features:  ['vitally', 'decisions', 'fully', 'difficult', 'participate', 'however']
# 9 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['could', 'security', 'errors', 'make', 'Western', 'Europe']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['foreign', 'buyers', 'slowdown', 'mergers', 'much', 'say']
# 8 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['think', 'Jeffrey', 'Peter', 'work', 'Joseph', 'brothers']
# 13 12
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['factors', 'yesterday', 'bearish', 'trading', 'top', 'late']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['provisions', 'far-reaching', 'federal', 'incorporating', 'mortgage', 'market']
# 6 5
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['wo', 'payment', 'provisions', 'loan-loss', 'dividends', 'increase']
# 8 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['regions', 'Hurricane', 'going', 'Hugo', 'amount', 'unspecified']
# 7 5
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['rapidly', 'value', 'deteriorate', 'houses', 'nearby', 'Unused']
# 7 5
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['also', 'would', 'perceptions', 'GNP', 'board', 'real']
# 8 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['especially', 'small', 'business', 'issues', 'initiative', 'San']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['portfolio', 'arrears', 'Bank', 'six', 'months', '--']
# 12 10
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['factor', 'new', 'joint-venture', 'one', 'plans', 'environment']
# 7 5
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['expected', 'sentencing', 'witness', 'GAF', 'performance', 'bellwether']
# 9 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['constant', 'market', 'supply', 'side', 'sectors', 'negative']
# 9 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['market', 'fusion', 'yesterday', 'cold', 'many', 'news']
# 8 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['wo', 'relationships', 'move', 'said', 'ad', 'executives']
# 8 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['value', 'think', 'existing', 'bonds', 'right', 'rating']
# 12 11
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['drama', 'wider', 'strategic', 'positions', 'part', 'fact']
# 11 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['broker-dealers', 'way', 'simply', 'Raoul-Duval', 'said', 'areas']
# 9 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['employee', 'loses', 'estimated', 'study', '16', 'work']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['talk', 'companies', 'Mid-sized', 'layoffs', 'company', 'plant']
# 8 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['stress', 'job', 'performance', 'measures', 'hard', 'get']
# 9 4
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['salesmen', 'accent', 'cases', 'seen', 'region', 'country']
# 10 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['adversely', 'company', 'capacity', 'existing', 'line', 'hot-dipped']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['decision', 'requirement', 'lend', 'conceded', 'minor', 'Bush']
# 9 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['decision', 'requirement', 'notification', 'lend', 'conceded', 'minor']
# 8 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['Department', 'concluding', 'Housing', 'years', 'recent', 'Urban']
# 8 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['continue', 'area', 'consequences', 'certain', 'psychological', 'respects']
# 8 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['deeply', 'felt', 'increasingly', 'Helion', 'pessimistic', 'atmosphere']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['caring', 'asking', 'without', 'times', 'many', 'story']
# 10 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['story', 'us', 'banal', 'rocking', 'would', 'exert']
# 10 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['ability', 'destinies', 'otherwise', 'believe', 'must', 'try']
# 9 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['naturalism', 'Century', 'Twentieth', 'every', 'period', 'supernaturalism']
# 10 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['unequally', 'may', 'action', 'community', 'government', 'portion']
# 10 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['unequally', 'Southern', 'region', 'order', 'Court', 'deny']
# 10 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['Us', 'Southern', 'viewpoint', 'Liberals', 'THIDIU', 'anywhere']
# 11 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['personally', 'Liberal', 'willing', 'prefer', 'send', 'confess']
# 11 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['personally', '--', 'South', 'people', 'North', 'denied']
# 9 8
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['Negro', 'changes', 'gradual', 'examples', 'moving', 'speechlessness']
# 11 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['changes', 'Southern', 'abrupt', 'life', 'gradual', 'also']
# 7 6
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['souls', 'Anything', 'concern', 'always', 'Church', 'reply']
# 11 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['tissues', 'Beer', 'none', 'said', 'heaven', 'ingenious']
# 10 9
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['government', 'procurement', 'doubt', 'jet', 'aircraft', 'transports']
# 8 7
# --------------------------------
# word:  affect
# non:  v
# sense:   1
# features:  ['Czarship', 'sense', 'social', 'values', 'receive', 'Mother']
# 11 10
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['Bush', 'President', 'argue', 'thrash', 'bigger', 'danger']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['trucks', 'Highway', 'carrying', 'Salang', 'food', 'strategic']
# 6 4
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Bush', 'take', 'effect', 'law', 'without', 'signature']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['country', 'Eisenhower', 'President', 'credible', 'cooperated', 'really']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['producers', 'stability', 'consumers', 'prices', 'firm', 'plan']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['rights', 'drill', 'Amoco', 'Sharpshooter', 'bought', 'mile']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['distribute', 'investigate', 'flag', 'police', 'asked', 'way']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['space', 'shorter', 'hoods', 'half', 'take', 'so-called']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['computer', 'patent', 'users', 'Quickview', 'display', 'violated']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['program', 'users', 'HyperCard', 'design', 'applications', 'field']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['several', 'signals', 'multiplexer', 'travel', 'along', 'later']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['president', 'compensate', 'win', 'controversial', 'victory', 'capital-gains']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'East', 'Germans', 'said', 'also', 'travel']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['order', 'former', 'court', 'National', 'Security', 'Adviser']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['big', 'stocks', 'investors', 'buy', 'baskets', 'sell']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['institutional', 'ESPs', 'investors', 'approval', 'buy', 'seal']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['memory', 'chips', 'overcome', 'could', 'approach', 'problems']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['arrangement', 'plea', 'instead', 'agreed', 'charges', 'therefore']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'process', 'acknowledge', 'motion', 'Sverdlovsk', 'violated']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'considerable', 'flexibility', 'determining', 'products', 'farm']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['trade', 'countries', 'agriculture', 'freer', 'convert', 'non-tariff']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'continue', 'impact', 'certain', 'trade', 'conditions']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['would', 'loans', 'imperfections', 'capital-market', 'correct', 'student']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['also', 'people', 'buy', 'choice', 'best', 'making']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['government', 'Japanese', 'Ministry', 'Agriculture', 'world', 'Fishery']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['instead', 'free', '--', 'market', 'price', 'worth']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['pay', 'Drexel', 'whether', 'move', 'said', 'whether']
# 11 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['--', 'us', 'common', 'sense', '--', 'prevail']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['potential', 'academic', 'student', 'ladder', 'educational', 'permitted']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Kasparov', 'trap', 'positional', 'exchange', 'deep', 'dark-squared']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['traffic', 'tolls', 'charge', 'zip', 'without', 'Bay']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['industry', 'technologies', 'eliminate', 'alternative', 'CFCs', 'find']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['judges', 'side', 'cases', 'three', 'civil', 'challenges']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['sometimes', 'many', 'judges', 'cases', 'complex', 'Etzioni']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['analyze', 'jurors', 'psychologists', 'personalities', 'says', 'Even']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['extensive', 'courts', 'jury', 'questioning', 'cautions', 'known']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['mushrooms', 'wo', 'agency', 'canned', 'yesterday', 'packed']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'bid', 'companies', 'private', 'assets', 'workers']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['prosecution', 'Britain', 'urged', 'suspected', 'investigators', 'Nazi']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['colony', 'dissident', 'Chinese', 'swimmer', 'month', 'flee']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Mallinckrodt', 'sale', 'focus', 'said', 'Minerals', 'resources']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['years', 'filing', 'three', 'claims', 'accounts', 'litigation']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Poindexter', 'agreed', 'judge', 'subpoena', 'Iran-Contra', 'personal']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['SCI', 'TV', 'value', 'sell', 'rise', 'assets']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['programmers', 'problem', 'broadcasters', 'alleviate', 'help', 'convert']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['depositions', 'network', 'nationwide', 'live', 'television', 'wire']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['underwriters', 'structure', 'deal', 'directly', 'suffered', 'clients']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['years', 'three', 'settlement', 'open', 'claims', 'books']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['interest', 'Reserve', 'rates', 'Federal', 'move', 'lower']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['budget', 'million', '150', 'McDonough', 'rely', 'extent']
# 10 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['public', 'states', 'participation', '36', 'attorney-disciplinary', 'joins']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'settlements', 'operate', 'negotiating', 'freely', 'nationwide']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['buildings', '15-minute', 'damaged', 'scavenger', 'badly', 'hunt']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Green', 'residents', 'color-coded', 're-enter', 'damage', 'yellow']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['yellow', 'limited', 'access', 're-enter', 'red', 'residents']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['red', 'residents', 'one', 'access', 'last', 'limited']
# 6 4
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['go', 'back', 'resident', 'inside', 'called', 'stairs']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'amendment', 'increase', 'proposed', 'debt', 'cap']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   2
# features:  ['currently', 'Falcon', '40', 'limited', 'value', 'partnership']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['activities', 'ease', 'projects', 'pain', 'programs', 'individual']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['amendment', 'floor', 'test', 'earnings', 'time', 'accountable']
# 10 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['members', 'family', 'immediate', 'must', 'catch', 'Continental']
# 10 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['names', 'demonstrate', 'choice', 'family', 'accommodate', 'affiliation']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['travelers', 'rule', 'transfer', 'change', 'frequent', 'flier']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'bill', 'said', 'Bush', 'become', 'law']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['policy', 'loans', 'regulations', 'without', 'new', 'tax']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'payments', 'others', 'catastrophic', 'stays', 'illnesses']
# 6 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['live', 'dream', 'got', 'people', 'says', 'excitement']
# 13 11
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['says', 'business', 'police', 'Englewood', 'would', 'planner']
# 10 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['steel', 'process', 'hot-dipped', 'covered', 'advantages', 'thicker']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['computers', 'program', 'software', 'network', 'today', 'announce']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['software', 'network', 'claims', 'run', 'Hewlett-Packard', 'three']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['even', 'may', 'state-controlled', 'openness', 'news', 'growing']
# 6 4
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['necessary', 'rigor', 'government', 'monetary', 'policy', 'audience']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['matter-of-factly', 'says', 'know', 'building', 'whitewalled', '650-or-so']
# 14 13
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['downtown', 'island', 'redevelopment', 'small', 'Beijing', 'relocated']
# 8 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['go', 'ahead', 'think', 'would', 'death', 'quiet']
# 12 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['general', 'Contras', 'says', 'Blandon', 'set', 'Nicaragua']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['North', 'anti-Noriega', 'Oliver', 'political', 'forces', 'resignation']
# 6 4
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['get', 'stronger', 'put', 'stronger', 'willing', 'people']
# 12 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['bill', 'federal', 'financing', 'veto', 'abortions', 'vowed']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'approve', 'affiliations', 'social', 'fully', 'Augustus']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['aside', 'natural', 'stand', 'forces', 'government', 'operate']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['psyches', 'way', 'moral', 'taste', 'readers', 'tea-leaf']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['simplicity', 'appeal', 'peculiar', 'arithmetized', 'discovery', 'heliocentric']
# 10 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['operate', 'speaking', 'Ideally', 'public', 'society', 'great']
# 11 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['must', 'granted', 'might', 'moment', 'every', 'experience']
# 14 12
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['art', 'reduced', 'elements', 'manifold', 'single', 'philosophy']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['mystery', 'invade', 'clear', 'us', 'classical', 'art']
# 11 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['people', 'confidence', 'abandon', 'degree', 'sufficient', 'ceremonies']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['longer', 'make', 'Scotty', 'regular', 'since', 'trips']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['man', 'sort', 'type', 'thing', 'John', 'happen']
# 8 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['spend', 'prospect', 'nights', 'elated', 'inn', 'near']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Precious', 'absolute', 'freedom', 'dramatic', 'mysterious', 'jealous']
# 12 11
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'name', 'company', 'dishonored', 'men', 'let']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['never', 'models', 'Yet', 'become', 'pull', 'fixed']
# 7 6
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['going', 'Protestant', 'Pope', 'Master', 'Calvin', 'demanded']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['nigras', 'walk', 'bastard', 'black', 'sidewalk', 'white']
# 11 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'best', 'antidote', 'streak', 'stubborn', 'bitterness']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['beardless', 'kids', 'Since', 'saloon', 'bars', 'closed']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['come', 'Providence', 'alive', 'stroke', 'remarkable', 'knew']
# 10 9
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['leave', 'Billy', 'unscathed', 'sore', 'jumped', 'Buck']
# 9 7
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['char', 'knees', 'without', 'administering', 'sank', 'stroke']
# 9 8
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Shall', 'beauty', 'great', 'bath', 'Actually', 'told']
# 15 13
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['would', 'attackers', 'pull', 'whether', 'away', 'wondered']
# 7 5
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['Finally', 'really', 'scurried', 'policeman', 'away', 'looking']
# 12 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['lock', 'Herman', 'lock', 'lock', 'toilet', 'would']
# 11 10
# --------------------------------
# word:  allow
# non:  v
# sense:   1
# features:  ['dear', 'would', 'baby', 'somehow', 'turn', 'feeling']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Venezuela', 'year', 'opening', 'Earlier', 'debt-equity', 'swaps']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Ortega', 'Friday', 'night', 'Saturday', 'would', 'Washington']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['plans', 'Exxon', 'month', '400-day', 'project', 'drilling']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Ministry', 'Foreign', 'According', 'Saturday', 'Nixon', 'beginning']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['last', 'spotty', 'year', 'Filipino', 'language', 'command']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['50', 'ministry', 'bans', 'food', 'imports', 'Since']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['tomorrow', 'expected', 'application', 'America', 'join', 'Latin']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['San', 'expected', 'Jose', 'application', 'Costa', 'Canadian']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['plans', 'final', 'venture', 'site', 'late', 'concerns']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['last', 'Friday', 'company', 'Swedish', 'pretax', 'profit']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['previously', 'favorable', 'less', 'discussions', 'substantially', 'Delmed']
# 9 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Sonet-based', 'also', 'products', 'AT&T', 'predicted', 'Alcatel']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Pilson', 'lastest', 'beaming', 'coup', 'news', 'deal']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['results', 'news', 'Norway', 'Turner', 'differences', 'Broadcasting']
# 11 10
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Bank', 'State', '90', 'Soviet', 'devaluation', 'Moscow']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['within', 'expected', 'next', 'week', 'package', 'final']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['could', 'early', 'today', 'changes', 'would', 'apply']
# 9 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['could', 'early', 'agreement', 'final', 'tomorrow', 'package']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['tons', 'similar', 'situation', 'totaling', 'apparently', 'arrivals']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Cable', 'Manhattan', 'launch', 'yesterday', 'Showtime', 'systems']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['yesterday', 'buy', 'studios', 'movies', 'Hollywood', 'Columbia']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['banks', 'leading', 'agreed', 'Norway', 'formal', 'two']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['previously', 'sale', 'Stirling', 'Houston', 'Scotland', 'Computer']
# 10 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['may', 'network', 'Teddy', 'week', 'next', 'moving']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['prosecutor', 'principles', 'either', 'expects', 'Division', 'time']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Airways', 'World', 'American', 'Pan', 'two', 'Soviet']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['since', 'Soviets', 'ventures', 'began', 'joint', 'encouraging']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Hampshire', 'New', 'made', 'yesterday', 'settlement', 'Rico']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['previously', 'bank', 'part', 'investment', 'punishment', 'Drexel']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Arkansas', 'Clinton', 'Bill', 'country', 'needs', 'education']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Communications', 'magazine', 'Lang', '17', 'magazine', 'years']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['conference', 'study', 'Nagoya', 'yesterday', 'familiar', 'scientists']
# 10 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['year', 'last', 'joint', 'venture', 'Power', 'Bechtel']
# 7 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['program', 'enhancement', 'close', 'export', 'trading', 'government']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['secretary', 'cabinet', 'eight', 'chief', 'cabinet', 'ministers']
# 6 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['previously', 'joint', 'venture', 'launch', 'power', 'semiconductors']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['conduits', 'investment', 'talk', 'mortgage', 'estate', 'several']
# 6 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['abruptly', 'old', 'leave', 'years', '59', 'venerable']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['intention', 'Saatchi', 'sell', 'Saatchi', 'revenue', 'annual']
# 11 9
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['also', 'Goodson', 'hired', 'contract', 'management', 'former']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['corporations', 'participation', 'major', 'three', 'Memories', 'two']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['reshuffling', 'board-level', 'executive', 'Pillsbury', 'duties', 'owns']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['enforcement', 'actions', 'regulators', 'Generally', 'past', 'public']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Burmah', 'SHV', 'held', 'stake', 'last', 'Monday']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['last', 'offering', 'week', 'Refcorp', 'when-issued', 'trading']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['July', 'last', 'deal', 'Bynoe', 'would', 'Lee']
# 7 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Cathay', 'earlier', 'year', 'Boeing', 'order', 'aircraft']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['recently', 'plans', 'Cathay', 'serve', 'destinations', 'San']
# 6 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Services', 'Human', 'higher', 'Health', 'payments', 'Department']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['world-wide', 'product', 'company', 'based', 'first', 'became']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['cut-rate', 'carriers', 'fares', 'many', 'designed', 'week']
# 7 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['previously', 'plan', 'sell', 'part', 'much', 'sale']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['today', 'Hewlett-Packard', 'software', 'program', 'allows', 'computers']
# 5 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Wall', 'Street', 'Jones', 'Journal', 'Dow', 'advertising']
# 6 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['decided', 'could', 'April', 'confirm', 'last', 'experiment']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['commissioner', 'baseball', 'third', 'game', 'billion', 'World']
# 9 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['directors', 'plans', 'Trelleborg', 'spin', 'Tuesday', 'two']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['initially', 'withdrawal', 'rose', 'Airways', 'British', 'UAL']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['rate', 'companies', 'increases', 'air-freight', 'scheduled', 'shipping']
# 7 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['similar', 'competitors', 'increases', 'two', 'least', 'Truckers']
# 6 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['failure', 'new', 'policy', 'chancellor', 'measures', 'eroded']
# 9 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['officials', 'last', 'Kong', 'week', 'Hong', 'Kong']
# 7 5
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Kilty', 'Jerome', 'Let', 'Bowman', 'emphaticize', 'one']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Soviets', 'last', 'soldier', 'left', 'Afghanistan', 'February']
# 5 9
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['countries', 'Five', 'would', 'sovereignty', 'honor', 'surrendered']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['unchangeable', 'law', '1902', 'Dixon', 'Thomas', 'child']
# 11 10
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['slowest', 'neighbors', 'cure', 'urgent', 'new', 'distresses']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['irony', 'emblematic', 'platitudinous', 'intent', 'sentence', 'way']
# 9 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['made', 'gold', 'could', 'circuit', 'decision', 'within']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['door', 'another', 'important', 'towards', 'fact', 'step']
# 6 4
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Rector', 'approached', 'wanted', 'time', 'baptized', 'Fletcher']
# 10 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Michelangelo', 'Today', 'leave', 'go', 'take', 'see']
# 8 7
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Mama', 'charge', 'three', 'hundred', 'members', 'eighty']
# 9 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Sicily', 'Beverly', 'Hills', 'Palermo', 'newly', 'swami']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['conclave', 'Church', 'secret', 'second', 'Major', 'bishops']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['disappearance', 'Digby', 'hear', 'Jubal', 'fleeting', 'suspicion']
# 15 14
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['lap', 'Throat', 'like', 'Blue', 'every', 'gun']
# 10 9
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Guess', 'Well', 'man', 'going', 'dead', 'Ed']
# 12 11
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['blandly', 'sort', 'proposition', 'got', 'business', 'corner']
# 12 11
# --------------------------------
# word:  announce
# non:  v
# sense:   2
# features:  ['rodeo', 'cheers', 'brought', 'Well', 'name', 'man']
# 11 9
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['repetition', 'nettled', 'way', 'head', 'shook', 'heard']
# 10 9
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Richard', 'fourteen', 'one', 'god', 'night', 'one']
# 11 9
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['Charlotte', 'gathering', 'one', 'Ryusenji', 'conversations', 'today']
# 9 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['engagement', 'Linda', 'said', 'jolt', 'people', 'John']
# 7 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['ready', 'need', 'big', 'bundle', 'dolls', 'burden']
# 13 11
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['cowboy', 'watching', 'Owen', 'play', 'martingale', 'steady']
# 8 6
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['studio', 'months', 'two', 'owed', 'part', 'better']
# 10 8
# --------------------------------
# word:  announce
# non:  v
# sense:   1
# features:  ['telephoned', 'accents', 'Letch', 'commonest', 'sired', 'unborn']
# 10 9
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['board', 'in-depth', 'said', 'discussion', 'also', 'BNL']
# 9 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['House', 'permanent', 'smoking', 'freedoms', 'ban', 'democratic']
# 7 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Hungary', 'legislation', 'granting', 'Lawmakers', 'amnesty', 'quit']
# 7 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['FDA', 'new', 'uses', 'shelves', 'psyllium', 'store']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['end', 'policy', 'like', 'required', 'senator', 'good']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['committee', 'covert', 'operations', 'says', 'Review', 'International']
# 10 8
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['law', 'Moscow', 'defied', 'month', 'move', 'banning']
# 8 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['today', 'expected', 'program', 'FDA', 'granting', 'access']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Senate', 'House-passed', 'measure', 'came', 'action', 'San']
# 9 8
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['temporarily', 'yesterday', 'SEC', 'help', 'ease', 'product']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['today', 'program', 'expected', 'granting', 'long-deferred', 'officials']
# 7 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['FDA', 'since', 'drug', 'AZT', 'usage', 'access']
# 7 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['adult', 'years', 'treatments', 'two', 'waited', 'pediatric']
# 6 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Congress', 'cheaper', 'funds', 'production', 'scaled-down', 'withheld']
# 7 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['time', 'similar', 'smaller', 'SEC', 'basket', 'product']
# 8 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Also', 'million', 'plan', 'trade', 'stock', 'portfolios']
# 9 8
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Senate', 'measure', 'margin', 'attaching', '97-1', 'lopsided']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['night', 'last', 'nearly', 'House', '67', 'billion']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['House', 'yesterday', 'general', 'scaled-back', 'measure', 'relief']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['House', 'short-term', 'spending', 'bill', 'keep', 'government']
# 4 9
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['bill', 'yesterday', 'underlying', 'required', 'budget', 'keep']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['conference', 'House-Senate', 'nearly', 'came', 'billion', 'action']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Department', 'Justice', 'districting', 'plan', 'June', 'Birmingham']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['must', 'recommendation', 'next', 'boss', 'supervisor', 'line']
# 9 8
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['medicine', 'prescription', 'treating', 'disease', 'world', 'Wellcome']
# 8 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['need', 'appointments', 'would', 'board', 'title', 'changes']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['meanwhile', 'billion', 'House', 'aid', '63', 'recovery']
# 10 9
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['plan', 'Sunday', 'peace', 'Lebanon', 'rejection', 'legislature']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Committee', 'Appropriations', 'House', 'billion', 'aid', 'roadway']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['plan', 'lawmakers', 'rejected', 'accord', 'Sunday', 'peace']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Committee', 'Appropriations', 'estimated', 'House', 'billion', 'emergency']
# 6 8
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['dispersants', 'test', 'Use', 'anyway', 'third', 'working']
# 9 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['voters', 'unless', 'statewide', 'taxes', 'referendum', 'raise']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['OPEC', 'new', 'get', 'permanent', 'production-sharing', 'ministers']
# 7 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['halfheartedly', 'another', 'ministers', 'increase', 'oil', 'one']
# 6 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['request', 'House', 'inflict', 'Senate', 'intended', 'Cheney']
# 11 10
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['changes', 'needed', 'majority', 'two-thirds', 'Constitution', 'short']
# 9 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Supervision', 'Thrift', 'conversion', 'last', 'Office', 'Friday']
# 6 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['LAWMAKERS', 'LEBANESE', 'peace', 'plan', 'Aoun', 'rejected']
# 4 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['expected', 'billion', 'also', 'international', 'offering', 'board']
# 8 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['increased', 'Kean', 'income', 'sales', 'Washington', 'taxes']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Lavoro', 'del', 'two-step', 'Nazionale', 'capital-boosting', 'Banca']
# 6 4
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['must', 'board', 'shareholders', 'members', 'assembly', 'bank']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['changes', 'needed', 'two-thirds', 'Constitution', 'short', 'well']
# 9 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['House', '837', 'burning', 'million', 'flag', 'aid']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['parliament', 'constitutional', 'changes', 'yesterday', 'meant', 'help']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['Senator', 'Tuesday', 'Bob', 'Dole', 'act', 'proposed']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['overwhelmingly', 'changes', 'Parliament', 'formally', 'ending', 'one-party']
# 6 5
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['group', 'international', 'formal', 'ban', 'officer', 'ivory']
# 7 6
# --------------------------------
# word:  approve
# non:  v
# sense:   2
# features:  ['fully', 'allow', 'Augustus', 'would', 'Baldwin', 'Longstreet']
# 8 7
# --------------------------------
# word:  approve
# non:  v
# sense:   1
# features:  ['pass', 'may', 'long', 'half', 'hour', 'wo']
# 12 10
# --------------------------------
# word:  approve
# non:  v
# sense:   2
# features:  ['warm', 'delightful', 'smile', 'voice', 'Tomorrow', 'better']
# 12 10
# --------------------------------
# word:  approve
# non:  v
# sense:   2
# features:  ['would', 'sure', 'kind', 'Dionigi', 'models', 'San']
# 10 8
# --------------------------------
# word:  area
# non:  n
# sense:   3
# features:  ['motor-control', 'brain', 'hand-held', 'electromagnets', 'generate', 'positioned']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   3
# features:  ['non-brain', 'Researchers', 'legs', 'apply', 'hand', 'permission']
# 8 7
# --------------------------------
# word:  area
# non:  n
# sense:   3
# features:  ['certain', 'subjects', 'flashes', 'brains', 'pigs', 'jolted']
# 8 7
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['disaster', 'hurricane', 'RODE', 'growers', 'HOBBY', 'timber']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['Soviets', 'greatest', 'strength', '--', '--', 'forces']
# 7 5
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['Washington', 'greatest', '--', 'superiority', 'forces', 'sea']
# 7 5
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Pravda', 'said', '27', 'soaring', 'said', 'rate']
# 10 8
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['China', 'Province', 'Guangdong', 'substantial', 'plant', 'Korean']
# 8 7
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['one', 'business', 'lagged', 'estate', 'notably', 'real']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Bay', 'Francisco', 'San', 'outstanding', 'work', 'resiliency']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['urban', 'Lawyers', 'measures', 'corrective', 'clients', 'serve']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Pacific', 'sees', 'looks', 'Coke', 'economic', 'demographic']
# 9 8
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['tristate', 'drinking', 'supply', 'water', 'Jersey', 'riddled']
# 8 7
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['expertise', 'special', 'mechanical', 'engineer', 'Teagan', 'chemistry']
# 12 10
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['chemicals', 'said', 'financing', 'production', 'would', 'consist']
# 8 7
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['rural', 'Senate', 'often', 'Appropriations', 'Committee', 'communities']
# 7 5
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['selected', 'growth', 'banks', 'good', 'amid', 'trading']
# 7 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['York', 'New', 'metropolitan', 'free', 'newspaper', 'dealers']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['York', 'New', 'allow', 'dealers', 'Times', 'newspaper']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['York', 'receive', 'New', 'paper', 'directly', 'subscribers']
# 7 5
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Bay', 'first', 'Prudhoe', 'project', 'reserves', 'Alaskan']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['expire', 'early', 'Wichita', 'December', 'Sound', 'Also']
# 8 7
# --------------------------------
# word:  area
# non:  n
# sense:   3
# features:  ['exact', '13', 'first', 'chromosome', 'copy', 'copy']
# 9 7
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Francisco', 'San', 'latching', 'onto', 'ads', 'coattails']
# 7 6
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['major', 'three', 'first', 'service', 'sector', 'gathered']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['three', 'Commerce', 'Department', 'found', 'tourism', '23']
# 9 8
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['trade', 'value', 'revisions', 'recalculations', 'net', 'exports']
# 9 8
# --------------------------------
# word:  area
# non:  n
# sense:   2
# features:  ['none', 'advance', 'technical', 'needed', 'represents', 'probably']
# 9 7
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Bay', 'Francisco', 'San', 'likely', 'end', 'came']
# 8 6
# --------------------------------
# word:  area
# non:  n
# sense:   1
# features:  ['Series', 'teams', 'got', 'two', 'year', 'lukewarm']
# 10 9
# --------------------------------
# word:  area
# non:  n
# sense:   2
# ...
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['wo', 'said', 'executives', 'affect', 'Mattel', 'relationships']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['hostile', 'certain', 'making', 'agreement', 'restricted', 'signed']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['hostile', 'unless', 'make', 'makes', 'ca', 'tender']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['bank', 'Texas', 'cited', 'market', 'concern', 'debt-rating']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['made', 'pressure', 'Interstate', 'First', 'regulators', 'estate']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['says', 'partly', 'aimed', 'airline', 'retaining', 'existing']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['1997', 'option', 'ahead', 'Cathay', 'offshore', 'reincorporated']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['London', 'rules', 'emphatically', 'Eddington', 'lifeblood', 'Hong']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['recent', 'orchestrating', 'Japanese', 'banks', 'role', 'played']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['meant', 'trim', '120', 'payroll', 'costs', 'camp']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['part', 'time', 'released', 'drive', 'increase', 'fluoride']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['Rosen', 'income', 'says', 'gross', 'bought', '20']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['helped', 'game', 'fair', 'Rosen', 'become', 'weather']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['money', 'smart', 'goes', 'show', 'add', 'First']
# 12 11
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['given', 'overall', 'market', 'fund', 'mutual', 'stock']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['betas', 'market-inspired', 'low', 'Concern', 'tend', 'investors']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['tons', 'nation', 'largest', 'capacity', 'steelmaker', 'annual']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['whether', 'win', 'back', 'expected', 'confidence', 'East']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['peace', 'Mideast', 'Labor', 'differences', 'Party', 'bridge']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['gutsy', 'little-known', 'executive', 'materials', 'fired', 'construction']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['boldest', 'yet', 'Andersson', 'month', 'Last', 'Trelleborg']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['cost-cutting', 'wo', 'result', 'disappointment', 'expressed', 'even']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['good', 'gets', 'growth', 'earnings', 'greater', 'people']
# 11 10
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['cost-reduction', 'cited', 'interest', 'company', 'income', 'Earnings']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['toward', 'democracy', 'Hungary', 'freemarket', 'Poland', 'economic']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['congressional', 'restore', 'preferential', 'tax', 'catalyst', 'treatment']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['part', '1993', 'Chase', 'completed', 'strategy', 'center']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['complements', 'share', 'company', 'cents', 'basic', '18']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['interpreted', 'system', 'banking', 'economists', 'reserves', 'drain']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['related', 'bank', 'also', 'state-controlled', 'proposed', '80']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['accelerating', 'personal', 'computer', 'monitors', 'manufacturers', 'make']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['union', 'strike', '1985', 'contested', 'following', 'seniority']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['subject', 'million', '134', 'definitive', 'agreement', 'million']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['positive', 'First', 'City', 'transaction', 'said', 'analysts']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['grips', 'vice', 'come', 'president', 'helped', 'large']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['previous', 'complements', 'union', 'government', 'Taming', 'attract']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['halt', 'divisions', 'imports', 'Ford', '--', 'existing']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['cost-cutting', 'citing', 'increased', 'sales', 'International', 'Baxter']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['dollar', 'market', 'influence', 'little', 'beginning', 'disassociate']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['drain', 'agreement', 'liquidity', 'sale-purchase', 'matched', 'four-day']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['technical', 'rather', 'viewed', 'indication', 'system', 'tightening']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['raised', 'Air', 'new', 'British', 'questions', 'partner']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['leadership', 'setback', 'Bush', 'pressure', 'Democrats', 'needs']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['follows', 'Rey', 'similar', 'Aussedat', 'technology-licensing', 'agreements']
# 6 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['would', 'impact', 'say', 'total', 'gold', 'output']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['early', 'essentially', 'established', 'buying', 'day', 'program']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['stunned', 'East', 'bloc', 'citizens', 'rebellious', 'hardly']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['million', 'widely', '71', 'expected', 'million', '150']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['market', 'accelerates', 'actually', 'trading', 'causing', 'program']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['trading', 'typically', 'event-driven', 'last', 'added', 'hours']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['shares', 'help', 'common', 'support', 'battered', 'billion']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['IBM', 'close', 'market', 'exactly', 'surprise', 'came']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['likely', 'term', 'short', 'little', 'effect', 'said']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['prevent', 'dislocation', 'financial', 'markets', 'California', 'earthquake']
# 4 13
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['could', 'year', 'consolidate', 'company', 'air-freight', 'industry']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['gives', 'meanwhile', 'strong', 'Eurocom', 'foothold', 'bulk']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['welcomed', 'called', 'specialists', 'necessary', 'computer', 'retreat']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['said', 'Craven', 'chairmanship', 'means', 'operations', 'securities']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['big', 'lagging', 'New', 'habit', 'York', 'Stock']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['recent', 'interest', 'light', 'rates', 'around', 'unit']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['likely', 'shares', 'help', 'common', 'computer', 'giant']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['including', 'block', 'Africa', 'settling', 'South', 'sanctions']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['could', 'pose', 'million', '225', 'new', 'challenge']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['likely', 'clients', 'anger', 'traders', 'account', 'FDIC']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['latest', 'increases', 'Ford', 'pressure', 'company', 'GM']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['latest', 'Jaguar', 'Ford', 'OTC', 'Symbol', 'course']
# 10 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['days', 'injects', 'two', 'capital', 'agreement', 'repurchase']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['Fed', 'loosen', 'credit', 'contend', 'analysts', 'aggressive']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['could', 'pose', 'new', 'competitive', 'challenge', 'Time']
# 4 10
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['lightning', 'show', 'minutes', 'stock', 'five', 'market']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['price', 'sudden', 'Scott', 'generate', 'Black', 'unlikely']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['50-point', 'less', 'ignore', 'percentage', 'terms', 'tend']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['stock-market', 'like', 'rapid', 'past', 'period', 'week']
# 6 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['reflected', 'proposal', 'growing', 'confidence', 'revise', '15']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['meant', 'period', 'intervention', 'keep', 'pre-noon', 'usual']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['aggressive', 'needed', 'said', 'Fed', 'Inc', 'also']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['Bankers', 'approving', 'Trust', 'Woods', 'Bruyette', 'capacity']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['Fed', 'small', 'gesture', 'system', 'banking', 'traders']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['bold', 'appear', 'necessary', 'grip', 'several', 'credit']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['largely', 'consigns', 'bicycles', 'mountain', 'roads', 'parks']
# 8 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['supported', 'Capitol', 'companies', 'Hill', 'auto', 'last']
# 6 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['would', 'shows', 'control', 'morning', 'costs', 'Saturday']
# 7 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['followed', 'quarter', 'round', 'similar', 'million', 'increases']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['opening', 'allowed', 'maximum', 'safeguards', 'adopted', 'open']
# 9 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['expand', 'million', 'presence', '322', 'rapidly', 'growing']
# 10 9
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['Lenders', 'comment', 'doubts', 'declined', 'Schroders', 'project']
# 9 8
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['optimistic', 'industry', 'already', 'facing', 'export', 'world-wide']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['--', 'suggests', 'stock', 'deep', 'preferred', 'concern']
# 6 5
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['almost', 'certain', 'exchanges', 'commodity', 'infuriate', 'exchange']
# 7 6
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['around', 'program', 'simple', 'solo', 'constructed', 'relatively']
# 8 7
# --------------------------------
# word:  move
# non:  n
# sense:   2
# features:  ['tusks', 'Convention', 'elephant', 'selling', 'Trade', 'channels']
# 9 7
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['elements', 'seek', 'develop', 'nuclear', 'subterfuge', 'weapons']
# 6 5
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['proteins', 'control', 'make', 'cell', 'growth', 'copy']
# 7 5
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['evidence', 'gene', 'confirming', 'losses', 'critical', 'biologists']
# 12 10
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['Psyllium', 'sandy', 'soil', 'crop', 'dew', 'demands']
# 8 6
# --------------------------------
# word:  need
# non:  v
# sense:   2
# features:  ['network', 'broaden', 'horizons', 'puts', 'Stringer', 'nonfiction']
# 9 8
# --------------------------------
# word:  need
# non:  v
# sense:   2
# features:  ['ENI', 'know', 'Europe', 'followed', 'coming', 'often']
# 8 6
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['Traub', 'Japanese', 'economics', 'European', 'look', 'partner']
# 8 7
# --------------------------------
# word:  need
# non:  v
# sense:   2
# features:  ['company', 'telephone', 'monitor', 'operators', 'says', 'evaluate']
# 7 6
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['laws', 'monitoring', 'new', 'say', 'heavily', 'concentrated']
# 7 6
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['say', 'bill', 'giant', 'consent', 'loophole', 'two-party']
# 8 6
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['sports', 'lose', 'Viewers', 'likely', 'may', 'cheering']
# 13 12
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['one', 'crown', 'entertainment', 'bought', 'lost', 'one']
# 9 8
# --------------------------------
# word:  need
# non:  v
# sense:   1
# features:  ['negotiator', 'good', 'level', 'says', 'focus', 'player']
# 8 6
# --------------------------------
# word:  need
# non:  v
# sense:   2
# features:  ['urgently', 'Tisch', 'make', 'bold', '1988', 'statement']
# 7 6
# --------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-209f45c60d3a> in <module>
#      32         if len(feature) == 6:
#      33             break
# ---> 34         if count2 < len(feature_right):
#      35             if ((len(feature_right[count2]) > 1) and (feature_right[count2].lower() not in Moein) and (set(list(feature_right[count2])) - set(Moein2)) == set(list(feature_right[count2]))):
#      36                 feature.append(feature_right[count2])
#
# KeyboardInterrupt:

# %%
Moein = stopwords.words('english')
'it' in Moein
# Out:
# True

# %%
Moein2 = [',','.','`',"'"]
set(list("virtual")) - set(Moein2) == set(list("virtual"))
# Out:
# True

# %%
# Out:
# {'a', 'i', 'l', 'r', 't', 'u', 'v'}

# %%
set(list("virtual")) == set(list("virtual")) - set(Moein2)
# Out:
# True

# %%
(set(list('Jr')) - set(Moein2)) == set(list('Jr'))
# Out:
# True
